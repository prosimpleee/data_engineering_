# %%
import time 
import requests
import boto3
from datetime import date
from botocore.client import Config
import json
from pyspark.sql import SparkSession
import pyspark.sql.functions as F
from pyspark.sql.functions import *
import pandas as pd
from io import BytesIO
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Extract traders data from: coinapi.io 
def extract_traders_data():
    url = "https://rest.coinapi.io/v1/trades/latest"
    headers = {"X-CoinAPI-Key" : dbutils.secrets.get(scope = "crypto_key", key = "key_api")}
    response = requests.get(url, headers=headers)
    data = response.json()
    bucket_name = "crypto-currency-data-prosimplee"
    file_name = "crypto/data/bronze/" + str(date.today()) + "_crypto_.json"
    s3 = boto3.resource("s3")
    try:
        s3.Bucket(bucket_name).put_object(Key=file_name, Body=json.dumps(data), ACL='private')
        print("Success")
    except ValueError:
        print("Extract Traders Data: FAILED!")
    
extract_traders_data()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Success
# </div>

# %%
# Get bronze values from S3 Bucket & Transform & Put silver data into S3 Bucket 
def silver_crypto():
    s3 = boto3.resource("s3")
    content_object = s3.Object("crypto-currency-data-prosimplee", "crypto/data/bronze/" + str(date.today()) + "_crypto_.json")
    try:
        file_content = content_object.get()["Body"].read().decode("utf-8")
        json_content = json.loads(file_content)
        crypto_silver_data = []
        for crypto_raw in json_content:
            crypto_silver_data.append({
                "user_id": crypto_raw["uuid"],    
                "symbol_id": crypto_raw["symbol_id"], 
                "action": crypto_raw["taker_side"], 
                "size": crypto_raw["size"],
                "time_exchange": crypto_raw["time_exchange"]})
        
        crypto_silver_df = pd.DataFrame(crypto_silver_data)   
        bucket_name = "crypto-currency-data-prosimplee"
        file_name = "crypto/data/silver/" + str(date.today()) + "_crypto_.parquet"
        s3 = boto3.resource("s3")
        out_buffer = BytesIO()
        try:
            crypto_silver_df.to_parquet(out_buffer, index=False)   
            s3.Bucket(bucket_name).put_object(Key=file_name, Body=out_buffer.getvalue(), ACL="private") 
        except ValueError:
            print("Parquet traders data (silver) values into S3: FAILED!")
                                                               
    except ValueError:
        print("Connection to S3 (traders data): FAILED!")
        
silver_crypto()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Create SparkSession
spark = SparkSession.builder.getOrCreate()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Get traders data (gold) from S3 Bucket & Create Table (crypto_data)
golden_crypto = spark.read \
.option("inferSchema", True) \
.parquet("s3a://crypto-currency-data-prosimplee/crypto/data/silver/" + str(date.today()) + "_crypto_.parquet") \
.createOrReplaceTempView("crypto_data")

spark.conf.set("spark.databricks.io.cache.enabled", False)

golden_crypto_table = spark.table("crypto_data")

golden_crypto_table.limit(10).toPandas()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[413]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>user_id</th>
#       <th>symbol_id</th>
#       <th>action</th>
#       <th>size</th>
#       <th>time_exchange</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>3eee35f7-49d8-40bf-8821-ae29bb959ba2</td>
#       <td>OKEX_SPOT_LAT_USDT</td>
#       <td>BUY</td>
#       <td>484.133500</td>
#       <td>2022-08-03T14:28:09.3170000Z</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>61bf0b3f-587e-4f2d-8f99-f8b35e262a94</td>
#       <td>DIGIFINEX_SPOT_BCH_USDT_566CCD</td>
#       <td>SELL</td>
#       <td>0.013030</td>
#       <td>2022-08-03T14:27:22.0000000Z</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>995eec52-f4ba-4c85-ab36-7b1afb8dbb86</td>
#       <td>DIGIFINEX_SPOT_BCH_USDT_566CCD</td>
#       <td>SELL</td>
#       <td>0.016390</td>
#       <td>2022-08-03T14:27:21.0000000Z</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3c13ef9d-7aef-4292-9563-bd77413dc990</td>
#       <td>DIGIFINEX_SPOT_BCH_USDT_566CCD</td>
#       <td>SELL</td>
#       <td>0.876280</td>
#       <td>2022-08-03T14:27:21.0000000Z</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0cf0ebeb-c5b9-40af-86d9-ff61314f04d2</td>
#       <td>DIGIFINEX_SPOT_CRV_USDT</td>
#       <td>BUY</td>
#       <td>5.000000</td>
#       <td>2022-08-03T14:27:34.0000000Z</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>06b7b220-c186-4be3-a51b-2dca7ab93367</td>
#       <td>DIGIFINEX_SPOT_CRV_USDT</td>
#       <td>SELL</td>
#       <td>395.047156</td>
#       <td>2022-08-03T14:27:15.0000000Z</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>a666bb1c-b0d4-4c16-8083-594e58be90a9</td>
#       <td>DIGIFINEX_SPOT_BCH_USDT_566CCD</td>
#       <td>BUY</td>
#       <td>0.013750</td>
#       <td>2022-08-03T14:27:21.0000000Z</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>1ad3f14c-b162-4a8c-98a0-c3fb8a7bf83c</td>
#       <td>DIGIFINEX_SPOT_CRV_USDT</td>
#       <td>SELL</td>
#       <td>7.473777</td>
#       <td>2022-08-03T14:24:39.0000000Z</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>645d2643-590b-462a-989d-8addd8babcc7</td>
#       <td>DIGIFINEX_SPOT_BCH_USDT_566CCD</td>
#       <td>BUY</td>
#       <td>0.014450</td>
#       <td>2022-08-03T14:27:20.0000000Z</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>3d03c253-bcf8-43e8-a682-0480f4684b05</td>
#       <td>DIGIFINEX_SPOT_CRV_USDT</td>
#       <td>SELL</td>
#       <td>788.762449</td>
#       <td>2022-08-03T14:24:36.0000000Z</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# Functions for take symbol_from and symbol_to 
def extract_symbol_from(column):
    symb_from = column.split("_")[2]
    return symb_from

sym_from_udf = F.udf(extract_symbol_from)

def extract_symbol_to(column):
    symb_to = column.split("_")[3]
    return symb_to

sym_to_udf = F.udf(extract_symbol_to)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Apply Functions on our columns
golden_crypto = golden_crypto_table \
    .withColumn("symbol_from",sym_from_udf(golden_crypto_table.symbol_id)) \
    .withColumn("symbol_to",sym_to_udf(golden_crypto_table.symbol_id))\
    .withColumn("time_exchange", to_timestamp(F.col("time_exchange").cast("timestamp")))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
golden_crypto.toPandas().head(10)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[416]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>user_id</th>
#       <th>symbol_id</th>
#       <th>action</th>
#       <th>size</th>
#       <th>time_exchange</th>
#       <th>symbol_from</th>
#       <th>symbol_to</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>3eee35f7-49d8-40bf-8821-ae29bb959ba2</td>
#       <td>OKEX_SPOT_LAT_USDT</td>
#       <td>BUY</td>
#       <td>484.133500</td>
#       <td>2022-08-03 14:28:09.317</td>
#       <td>LAT</td>
#       <td>USDT</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>61bf0b3f-587e-4f2d-8f99-f8b35e262a94</td>
#       <td>DIGIFINEX_SPOT_BCH_USDT_566CCD</td>
#       <td>SELL</td>
#       <td>0.013030</td>
#       <td>2022-08-03 14:27:22.000</td>
#       <td>BCH</td>
#       <td>USDT</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>995eec52-f4ba-4c85-ab36-7b1afb8dbb86</td>
#       <td>DIGIFINEX_SPOT_BCH_USDT_566CCD</td>
#       <td>SELL</td>
#       <td>0.016390</td>
#       <td>2022-08-03 14:27:21.000</td>
#       <td>BCH</td>
#       <td>USDT</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3c13ef9d-7aef-4292-9563-bd77413dc990</td>
#       <td>DIGIFINEX_SPOT_BCH_USDT_566CCD</td>
#       <td>SELL</td>
#       <td>0.876280</td>
#       <td>2022-08-03 14:27:21.000</td>
#       <td>BCH</td>
#       <td>USDT</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0cf0ebeb-c5b9-40af-86d9-ff61314f04d2</td>
#       <td>DIGIFINEX_SPOT_CRV_USDT</td>
#       <td>BUY</td>
#       <td>5.000000</td>
#       <td>2022-08-03 14:27:34.000</td>
#       <td>CRV</td>
#       <td>USDT</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>06b7b220-c186-4be3-a51b-2dca7ab93367</td>
#       <td>DIGIFINEX_SPOT_CRV_USDT</td>
#       <td>SELL</td>
#       <td>395.047156</td>
#       <td>2022-08-03 14:27:15.000</td>
#       <td>CRV</td>
#       <td>USDT</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>a666bb1c-b0d4-4c16-8083-594e58be90a9</td>
#       <td>DIGIFINEX_SPOT_BCH_USDT_566CCD</td>
#       <td>BUY</td>
#       <td>0.013750</td>
#       <td>2022-08-03 14:27:21.000</td>
#       <td>BCH</td>
#       <td>USDT</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>1ad3f14c-b162-4a8c-98a0-c3fb8a7bf83c</td>
#       <td>DIGIFINEX_SPOT_CRV_USDT</td>
#       <td>SELL</td>
#       <td>7.473777</td>
#       <td>2022-08-03 14:24:39.000</td>
#       <td>CRV</td>
#       <td>USDT</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>645d2643-590b-462a-989d-8addd8babcc7</td>
#       <td>DIGIFINEX_SPOT_BCH_USDT_566CCD</td>
#       <td>BUY</td>
#       <td>0.014450</td>
#       <td>2022-08-03 14:27:20.000</td>
#       <td>BCH</td>
#       <td>USDT</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>3d03c253-bcf8-43e8-a682-0480f4684b05</td>
#       <td>DIGIFINEX_SPOT_CRV_USDT</td>
#       <td>SELL</td>
#       <td>788.762449</td>
#       <td>2022-08-03 14:24:36.000</td>
#       <td>CRV</td>
#       <td>USDT</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# Loading traders data into MSSQL database
db_crypto_data = golden_crypto.select(F.col("user_id"), 
                                      F.col("action"), 
                                      F.col("size"), 
                                      F.col("symbol_from"), 
                                      F.col("symbol_to"), 
                                      F.col("time_exchange"))



database = dbutils.secrets.get(scope = "database", key = "name")
table = "dbo.crypto_data"
user = dbutils.secrets.get(scope = "username", key = "usr")
password  = dbutils.secrets.get(scope = "mssql", key = "password")
server_name = dbutils.secrets.get(scope = "server", key = "name")


db_crypto_data.write.mode("append") \
    .format("jdbc") \
    .option("url", f"jdbc:sqlserver://{server_name};databaseName={database};") \
    .option("dbtable", table) \
    .option("user", user) \
    .option("password", password) \
    .option("driver", "com.microsoft.sqlserver.jdbc.SQLServerDriver") \
    .save()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Extract (bronze) a directory of all cryptocurrency names
def via_api_extract_crypto_names():
    url = "https://rest.coinapi.io/v1/assets"
    headers = {"X-CoinAPI-Key" : dbutils.secrets.get(scope = "crypto_key", key = "key_api")}
    response = requests.get(url, headers=headers)
    data = response.json()
    bucket_name = "crypto-currency-data-prosimplee"
    file_name = "crypto/catalog/stag/crypto_catalog.json"
    s3 = boto3.resource("s3")
    try:
        s3.Bucket(bucket_name).put_object(Key=file_name, Body=json.dumps(data), ACL="private")
        print("Success")
    except ValueError:
        print("Extract Crypto Names via Api: FAILED!")
    
via_api_extract_crypto_names()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Success
# </div>

# %%
# Extract (parquet) a directory of all cryptocurrency names
def from_s3_extract_crypto_names():
    s3 = boto3.resource("s3")
    content_object = s3.Object("crypto-currency-data-prosimplee", "crypto/catalog/stag/crypto_catalog.json")
    try:
        file_content = content_object.get()["Body"].read().decode("utf-8")
        json_content = json.loads(file_content)
        crypto_names = []
        for cr_n in json_content:
            try:
                dictionary_crypto = {"symbol_id" : cr_n["asset_id"], 
                                     "symbol_name" : cr_n["name"]}
                crypto_names.append(dictionary_crypto)
            except ValueError:
                print("Crypto Name ValueError!")

        crypto_name_dictionary = pd.DataFrame(crypto_names)
        bucket_name = "crypto-currency-data-prosimplee"
        file_name = "crypto/catalog/clean/crypto_catalog.parquet"
        s3 = boto3.resource("s3")
        out_buffer = BytesIO()
        try:
            crypto_name_dictionary.to_parquet(out_buffer, index=False)   
            s3.Bucket(bucket_name).put_object(Key=file_name, Body=out_buffer.getvalue(), ACL="private")
        except ValueError:
            print("Parquet Crypto Names (silver) values into S3: FAILED!")                                                        
    except ValueError:
        print("Connection to S3 (crypto names): FAILED!")
        
from_s3_extract_crypto_names()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Create Table (crypto_names)
crypto_names = spark.read\
.option("inferSchema", True)\
.parquet("s3a://crypto-currency-data-prosimplee/crypto/catalog/clean/crypto_catalog.parquet")\
.createOrReplaceTempView("crypto_names")

cr_names_table = spark.table("crypto_names")

cr_names_table.limit(10).toPandas()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[420]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>symbol_id</th>
#       <th>symbol_name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>USD</td>
#       <td>US Dollar</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>BTC</td>
#       <td>Bitcoin</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>PLN</td>
#       <td>Zloty</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>EUR</td>
#       <td>Euro</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>CNY</td>
#       <td>Yuan Renminbi</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>JPY</td>
#       <td>Yen</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>AUD</td>
#       <td>Australian Dollar</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>CHF</td>
#       <td>Swiss Franc</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>SEK</td>
#       <td>Swedish Krona</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>GBP</td>
#       <td>Pound Sterling</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# Search for the average sale size of cryptocurrencies
avg_size_sell = golden_crypto \
    .groupBy(F.col("symbol_from"), F.col("symbol_to"), F.col("action")) \
    .agg(F.avg(F.col("size")).alias("avg_size")) \
    .where(F.col("action") == "SELL")

avg_size_sell.limit(10).toPandas()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[421]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>symbol_from</th>
#       <th>symbol_to</th>
#       <th>action</th>
#       <th>avg_size</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>BCH</td>
#       <td>USDT</td>
#       <td>SELL</td>
#       <td>1.645177</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>JST</td>
#       <td>USDT</td>
#       <td>SELL</td>
#       <td>1464.921900</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>ROOM</td>
#       <td>ETH</td>
#       <td>SELL</td>
#       <td>702.095000</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>FTM</td>
#       <td>USDT</td>
#       <td>SELL</td>
#       <td>43.562683</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>ETH</td>
#       <td>USDT</td>
#       <td>SELL</td>
#       <td>97.000000</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>ATOM</td>
#       <td>USDC</td>
#       <td>SELL</td>
#       <td>0.011000</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>MKR</td>
#       <td>ETH</td>
#       <td>SELL</td>
#       <td>0.000100</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>CRV</td>
#       <td>USDT</td>
#       <td>SELL</td>
#       <td>397.094461</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>WE</td>
#       <td>USDT</td>
#       <td>SELL</td>
#       <td>0.176183</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>LEOS</td>
#       <td>USDT</td>
#       <td>SELL</td>
#       <td>207.000000</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
result_sell = avg_size_sell.join(cr_names_table, avg_size_sell.symbol_from == cr_names_table.symbol_id, how = "inner").select(F.col("symbol_from"), 
                                                                                                                              F.col("symbol_name").alias("symbol_from_name"), 
                                                                                                                              F.col("symbol_to"), 
                                                                                                                              F.col("avg_size"))
sell_df = result_sell.join(cr_names_table, avg_size_sell.symbol_to == cr_names_table.symbol_id, how = "inner").select(F.col("symbol_from"),
                                                                                                                      F.col("symbol_from_name"), 
                                                                                                                      F.col("symbol_to"),
                                                                                                                      F.col("symbol_name").alias("symbol_to_name"), 
                                                                                                                      F.col("avg_size"))
sell_df.limit(10).toPandas()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[422]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>symbol_from</th>
#       <th>symbol_from_name</th>
#       <th>symbol_to</th>
#       <th>symbol_to_name</th>
#       <th>avg_size</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>BTC</td>
#       <td>Bitcoin</td>
#       <td>USDT</td>
#       <td>Tether</td>
#       <td>0.003000</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>ETH</td>
#       <td>Ethereum</td>
#       <td>USDT</td>
#       <td>Tether</td>
#       <td>97.000000</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>ATOM</td>
#       <td>Cosmos</td>
#       <td>USDC</td>
#       <td>USDC</td>
#       <td>0.011000</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>NMR</td>
#       <td>Numeraire</td>
#       <td>BUSD</td>
#       <td>Binance USD</td>
#       <td>0.520000</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>BCH</td>
#       <td>Bitcoin Cash</td>
#       <td>USDT</td>
#       <td>Tether</td>
#       <td>1.645177</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>MKR</td>
#       <td>Maker</td>
#       <td>ETH</td>
#       <td>Ethereum</td>
#       <td>0.000100</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>FTM</td>
#       <td>FTM</td>
#       <td>USDT</td>
#       <td>Tether</td>
#       <td>43.562683</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>CRV</td>
#       <td>CRV</td>
#       <td>USDT</td>
#       <td>Tether</td>
#       <td>397.094461</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>JST</td>
#       <td>JST</td>
#       <td>USDT</td>
#       <td>Tether</td>
#       <td>1464.921900</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>FLOW</td>
#       <td>FLOW</td>
#       <td>USDC</td>
#       <td>USDC</td>
#       <td>0.040000</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# The received data is written to the S3 bucket
sell_df.write \
 .mode("OVERWRITE") \
 .option("header","true") \
 .parquet("s3a://crypto-currency-data-prosimplee/crypto/data/gold/sell_" + str(date.today()) + "_crypto_.parquet")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Search for the average buy size of cryptocurrencies
avg_size_buy = golden_crypto \
    .groupBy(F.col("symbol_from"), F.col("symbol_to"), F.col("action")) \
    .agg(F.avg(F.col("size")).alias("avg_size")) \
    .where(F.col("action") == "BUY")

avg_size_buy.limit(10).toPandas()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[424]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>symbol_from</th>
#       <th>symbol_to</th>
#       <th>action</th>
#       <th>avg_size</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>GF</td>
#       <td>USDT</td>
#       <td>BUY</td>
#       <td>369.935769</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>LAT</td>
#       <td>USDT</td>
#       <td>BUY</td>
#       <td>484.133500</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>USDC</td>
#       <td>USDT</td>
#       <td>BUY</td>
#       <td>14.920218</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>CELR</td>
#       <td>USDC</td>
#       <td>BUY</td>
#       <td>5.000000</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>CRV</td>
#       <td>USDT</td>
#       <td>BUY</td>
#       <td>324.409150</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>CRO</td>
#       <td>BTC</td>
#       <td>BUY</td>
#       <td>0.050000</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>WE</td>
#       <td>USDT</td>
#       <td>BUY</td>
#       <td>0.085414</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>CYCLUB</td>
#       <td>USDT</td>
#       <td>BUY</td>
#       <td>161.000200</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>LDO</td>
#       <td>USDT</td>
#       <td>BUY</td>
#       <td>67.320000</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>BCH</td>
#       <td>USDT</td>
#       <td>BUY</td>
#       <td>2.136763</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
avg_size_buy = avg_size_buy.join(cr_names_table, avg_size_buy.symbol_from == cr_names_table.symbol_id, how = "inner").select(F.col("symbol_from"), 
                                                                                                                             F.col("symbol_name").alias("symbol_from_name"), 
                                                                                                                             F.col("symbol_to"), 
                                                                                                                             F.col("avg_size"))
buy_df = avg_size_buy.join(cr_names_table, avg_size_buy.symbol_to == cr_names_table.symbol_id, how = "inner").select(F.col("symbol_from"),
                                                                                                                     F.col("symbol_from_name"), 
                                                                                                                     F.col("symbol_to"),
                                                                                                                     F.col("symbol_name").alias("symbol_to_name"), 
                                                                                                                     F.col("avg_size"))
buy_df.limit(10).toPandas()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[425]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>symbol_from</th>
#       <th>symbol_from_name</th>
#       <th>symbol_to</th>
#       <th>symbol_to_name</th>
#       <th>avg_size</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>ETH</td>
#       <td>Ethereum</td>
#       <td>USDT</td>
#       <td>Tether</td>
#       <td>0.119000</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>KNC</td>
#       <td>Kyber Network</td>
#       <td>USDT</td>
#       <td>Tether</td>
#       <td>20.260000</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>BCH</td>
#       <td>Bitcoin Cash</td>
#       <td>USDT</td>
#       <td>Tether</td>
#       <td>2.136763</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>LAT</td>
#       <td>LAT</td>
#       <td>USDT</td>
#       <td>Tether</td>
#       <td>484.133500</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>THETA</td>
#       <td>Theta Token</td>
#       <td>USDC</td>
#       <td>USDC</td>
#       <td>0.846988</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>ACH</td>
#       <td>ACH</td>
#       <td>USDT</td>
#       <td>Tether</td>
#       <td>1854.000000</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>USDC</td>
#       <td>USDC</td>
#       <td>USDT</td>
#       <td>Tether</td>
#       <td>14.920218</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>CRO</td>
#       <td>Crypto.com Chain</td>
#       <td>BTC</td>
#       <td>Bitcoin</td>
#       <td>0.050000</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>CRV</td>
#       <td>CRV</td>
#       <td>BTC</td>
#       <td>Bitcoin</td>
#       <td>10.131000</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>CRV</td>
#       <td>CRV</td>
#       <td>USDT</td>
#       <td>Tether</td>
#       <td>324.409150</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# The received data is written to the S3 bucket
avg_size_buy.write \
 .mode("OVERWRITE") \
 .option("header","true") \
 .parquet("s3a://crypto-currency-data-prosimplee/crypto/data/gold/buy_" + str(date.today()) + "_crypto_.parquet")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
